# %% [markdown]
# ## Hello World

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       2 import numpy as np
#       3 model = SentenceTransformer("all-MiniLM-L6-v2")
#
# File c:\Users\USER\Documents\Git\Tutorial\my-talk-to-django\venv\Lib\site-packages\sentence_transformers\__init__.py:9
#       6 import importlib
#       7 import os
# ----> 9 from sentence_transformers.backend import (
#      10     export_dynamic_quantized_onnx_model,
#      11     export_optimized_onnx_model,
#      12     export_static_quantized_openvino_model,
#      13 )
#      14 from sentence_transformers.cross_encoder import (
#      15     CrossEncoder,
#      16     CrossEncoderModelCardData,
#      17     CrossEncoderTrainer,
#      18     CrossEncoderTrainingArguments,
#      19 )
# ...
